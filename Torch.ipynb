# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
x = torch.ones(16, 32)
w = torch.ones(32, 2)

y = x @ w

print(y.size() == torch.Size([16, 2]))
# Out:
# True

# %%
x = torch.ones(4, 8, 16, 32)
w = torch.ones(32, 2)

y = x @ w

print(y.size() == torch.Size([4, 8, 16, 2]))
# Out:
# True
